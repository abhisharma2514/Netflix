# %% [markdown]
# <img src="dataset/netflix.png" height="400" width="400">

# %% [markdown]
# # Netflix Dataset Analysis using Pandas :-

# %% [markdown]
# To perform analysis on the Netflix dataset using Pandas, you first need to load the dataset into a Pandas DataFrame and then you can perform various operations like data cleaning, manipulation, and analysis.

# %% [markdown]
# ### This Netflix Dataset has information about the TV Shows and Movies available on Netflix till 2021.

# %% [markdown]
# ### This dataset is collected from Flixable which is a third-party
# ### Netflix search engine, and available on Kaggle website for free

# %% [markdown]
# 1. Import Libraries: Start by importing the necessary libraries, mainly Pandas for data manipulation.
#
# 2. Load the Dataset: Load the Netflix dataset into a Pandas DataFrame.
#
# 3. Data Cleaning: Check for missing values, duplicate entries, and perform necessary cleaning operations.
#
# 4. Data Analysis: Perform analysis based on the questions you want to answer or insights you want to gain from the    dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("dataset/netflix.csv")

# %% [markdown]
# ### This will display the first 5 records of the dataset. You can adjust the number passed to the head() function if you want to display more or fewer records.

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %% [markdown]
# ### This will display the last 5 records of the dataset. Just like with 'head()', you can adjust the number passed to the 'tail()' function to display more or fewer records from the end of the dataset.

# %%
df.tail()
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %% [markdown]
# ### This will print the number of rows and columns in the DataFrame 'df'. The 'shape' attribute of a DataFrame returns a tuple where the first element represents the number of rows ('shape[0]') and the second element represents the number of columns ('shape[1]').

# %%
print("No. of Row :",df.shape[0],"\nNo. of Column :",df.shape[1])
# Out:
# No. of Row : 7789
# No. of Column : 11

# %% [markdown]
# ### This code will print each column name of the DataFrame 'df' on separate lines. The 'columns' attribute returns an Index object containing the column labels of the DataFrame. You can iterate over this object to access each column name.

# %%
df.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %% [markdown]
# ### This code will print the data type of each column in the DataFrame 'df.' The 'dtypes' attribute returns a Series containing the data type of each column, indexed by column names.

# %%
df.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %% [markdown]
# ### The 'info()' method provides a concise summary of the DataFrame, including the range of the index, column names, data types of each column, and memory usage. It's a handy way to get an overview of the DataFrame's structure and characteristics.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %% [markdown]
# ### This code first checks for duplicate records using the 'duplicated()' function, which returns a DataFrame of boolean values indicating whether each row is a duplicate or not. If there are any duplicate records, they are printed, and then the 'drop_duplicates()' function is used to remove them inplace. If no duplicates are found, it prints a message indicating so.

# %%
df[df.duplicated()]  # show duplicate record
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
df.drop_duplicates(inplace=True)  # Drop Duplicate Records

# %%
df[df.duplicated()]  # Not found
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %% [markdown]
# ### This code snippet checks for null values in any column using 'isnull().any()'. If any null values are found, it prints the names of the columns where null values are present. If there are no null values in any column, it prints a message indicating so.

# %%
df.isnull().any()
# Out:
# Show_Id         False
# Category        False
# Title           False
# Director         True
# Cast             True
# Country          True
# Release_Date     True
# Rating           True
# Duration        False
# Type            False
# Description     False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %% [markdown]
# ### You can use the 'str.contains()' method in pandas to filter rows based on whether the title contains "House of Cards".

# %%
df.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %% [markdown]
# ### Replace 'df' with the name of your DataFrame if it's different. This code will print the rows of the DataFrame where the title contains "House of Cards".

# %% [markdown]
# ###  use str.contains()

# %%
df[df['Title'].str.contains('House of Cards')]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# ### To determine the year with the highest number of TV shows and movies released from your dataset and visualize it with a bar graph using pandas, you can use the following approach:

# %%
df.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %% [markdown]
# ### It seems like you want to convert the 'Release_Date' column in your DataFrame 'df' to a datetime format and assign it to a new column 'Date_N'. You can achieve this using the 'pd.to_datetime()' function in pandas.

# %% [markdown]
# ### to_datetime
#
# Make new column & data-type is datetime

# %%
df['Date_N']=pd.to_datetime(df['Release_Date'],format='mixed')

# %%
df.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date_N          datetime64[ns]
# dtype: object

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %% [markdown]
# ### This will give you a count of how many TV shows were released in each year, based on the 'Date_N' column of your DataFrame.

# %% [markdown]
# ### dt.year.value_counts()

# %%
df['Date_N'].dt.year.value_counts()
# Out:
# Date_N
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: count, dtype: int64

# %% [markdown]
# ### To plot the counts of TV shows released each year as a bar plot, you can use the 'plot()' function directly on the result of 'value_counts()' with 'kind='bar''.

# %% [markdown]
# ###  Bar Graph

# %%
df['Date_N'].dt.year.value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# ### To determine the number of movies and TV shows in your dataset and visualize them with a bar graph using pandas, you can use the following approach:

# %%
a=df['Category'].value_counts()
a
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: count, dtype: int64

# %%
a.plot(kind='bar')
plt.title('Number of Movies and TV Shows in the Dataset')
plt.xlabel('Category')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### To filter and display all the movies that were released in the year 2000 from your DataFrame using pandas, you can use the following approach:

# %% [markdown]
# ### Creating New Column

# %%
# to creat new year column ; it will consider year

# %% [markdown]
# ### You've added a new column 'Year' to your DataFrame 'df', which contains the year extracted from the 'Date_N' column. Now, you can use this 'Year' column to filter out the movies released in the year 2000.

# %%
df['Year']=df['Date_N'].dt.year

# %%
df.head(1)
# Out:
#   Show_Id Category Title Director  \
# 0      s1  TV Show    3%      NaN
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          Description     Date_N    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0

# %%
df[df['Year']==2000]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_N, Year]
# Index: []

# %% [markdown]
# ### To display only the titles of TV shows that were released in India only, you need to filter your DataFrame to include TV shows released in India but not in any other country.

# %%
a=df[(df['Country']=='India') & (df['Category']=='TV Show')].index.tolist()
df.loc[a,['Category','Title','Country']]
# Out:
#      Category                               Title Country
# 86    TV Show        21 Sarfarosh: Saragarhi 1897   India
# 132   TV Show                           7 (Seven)   India
# 340   TV Show                        Agent Raghav   India
# 364   TV Show                        Akbar Birbal   India
# 533   TV Show                 Anjaan: Rural Myths   India
# ...       ...                                 ...     ...
# 6249  TV Show                The Creative Indians   India
# 6400  TV Show  The Golden Years with Javed Akhtar   India
# 6469  TV Show              The House That Made Me   India
# 7294  TV Show                          Typewriter   India
# 7705  TV Show                     Yeh Meri Family   India
#
# [71 rows x 3 columns]

# %% [markdown]
# ### To find the top 10 directors who have given the highest number of TV shows and movies to Netflix, you would need a DataFrame containing information about TV shows and movies, including the directors and the platform they were released on (in this case, Netflix). Then, you can count the occurrences of each director and sort them to find the top 10.

# %%
df['Director'].value_counts().head(10)
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Hakan Algül                8
# Name: count, dtype: int64

# %% [markdown]
# ### To show all the records where the category is "Movie" and type is "Comedies", or where the country is "United Kingdom", you can use the ' | ' operator for OR condition and ' & ' operator for AND condition within the parentheses to control the logic.

# %%
df[(df['Category']=='Movie') & (df['Type']=='Comedies') | (df['Country']=='United Kingdom')]
# Out:
#      Show_Id Category                   Title          Director  \
# 19       s20    Movie                     '89               NaN
# 33       s34    Movie            #realityhigh  Fernando Lebrija
# 58       s59  TV Show             100% Hotter               NaN
# 72       s73    Movie                17 Again       Burr Steers
# 82       s83    Movie     2036 Origin Unknown     Hasraf Dulull
# ...      ...      ...                     ...               ...
# 7670   s7669  TV Show  World War II in Colour               NaN
# 7671   s7670  TV Show  World's Busiest Cities               NaN
# 7688   s7687    Movie  XV: Beyond the Tryline  Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu       James Brown
# 7740   s7739  TV Show         Young Wallander               NaN
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %% [markdown]
# ### To find out how many movies or shows Tom Cruise was cast in your DataFrame, you can filter the DataFrame by searching for his name in the cast or actor column.

# %%
df[df['Cast']=='Tom Cruise']  # not show data because missing records or null value
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_N, Year]
# Index: []

# %% [markdown]
# ### str.contains()

# %%
df[df['Cast'].str.contains('Tom Cruise',na=False)]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description     Date_N    Year
# 3860  Through chance, human action, past history and... 2020-01-01  2020.0
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01  2019.0

# %% [markdown]
# ### It drops the row that contains all or any missing values.
# ### Drop missing records
# ### Creating New DataFrame

# %%
new_data=df.dropna()

# %%
new_data.head(1)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating Duration                          Type  \
# 1  December 23, 2016  TV-MA   93 min  Dramas, International Movies
#
#                                          Description     Date_N    Year
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %% [markdown]
# ### To find out the number of unique ratings defined by Netflix in a pandas DataFrame named 'df', you can use the 'nunique()' function.

# %%
df.Rating.nunique()
# Out:
# 14

# %%
df.Rating.unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# ### To count how many movies have the 'TV-14' rating in Canada within a pandas DataFrame, you can use conditional filtering. Assuming your DataFrame is named 'df' and it contains columns for 'Rating' and 'Country'.

# %%
df[(df['Category']=='Movie') & (df['Rating']=='TV-14') & (df['Country']=='Canada')]
# Out:
#      Show_Id Category                                        Title  \
# 30       s31    Movie                             #cats_the_mewvie
# 34       s35    Movie                                        #Roxy
# 608     s609    Movie                               At First Light
# 1506   s1507    Movie                   Counterfeiting in Suburbia
# 3713   s3714    Movie                            Long Time Running
# 3956   s3957    Movie  Martin Matte: La vie, la mort...eh la la..!
# 5336   s5336    Movie                   Sadie's Last Days on Earth
# 5393   s5393    Movie                                   Sardaar ji
# 6062   s6062    Movie                  The Accountant of Auschwitz
# 7025   s7024    Movie                         The Wrong Babysitter
# 7041   s7040    Movie               There's Something in the Water
#
#                                     Director  \
# 30                          Michael Margolis
# 34                           Michael Kennedy
# ...

# %%
df[(df['Category']=='Movie') & (df['Rating']=='TV-14') & (df['Country']=='Canada')].shape
# Out:
# (11, 13)

# %% [markdown]
# ### To determine the number of TV shows that received an 'R' rating after the year 2018 using Python with pandas, you would typically need access to a dataset containing information about TV shows and their ratings. Assuming you have such a dataset, you can filter it based on the criteria and count the number of TV shows that meet the condition.

# %%
df.head(1)
# Out:
#   Show_Id Category Title Director  \
# 0      s1  TV Show    3%      NaN
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          Description     Date_N    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0

# %%
df[(df['Category']=='TV Show') & (df['Rating']=='R')]
# Out:
#      Show_Id Category                                Title           Director  \
# 4497   s4498  TV Show                                Nobel                NaN
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country  \
# 4497  Aksel Hennie, Tuva Novotny, Anders Danielsen L...  Norway
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#            Release_Date Rating  Duration  \
# 4497  December 10, 2016      R  1 Season
# 6437     April 25, 2019      R  1 Season
#
#                                                  Type  \
# 4497  International TV Shows, TV Dramas, TV Thrillers
# 6437                                         TV Shows
#
#                                             Description     Date_N    Year
# 4497  A series of incidents in Afghanistan set compl... 2016-12-10  2016.0
# 6437  Trapped at a stagecoach stop as a storm rages ... 2019-04-25  2019.0

# %%
df[(df['Category']=='TV Show') & (df['Rating']=='R') & (df['Year']>2018)]
# Out:
#      Show_Id Category                                Title           Director  \
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country  \
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#         Release_Date Rating  Duration      Type  \
# 6437  April 25, 2019      R  1 Season  TV Shows
#
#                                             Description     Date_N    Year
# 6437  Trapped at a stagecoach stop as a storm rages ... 2019-04-25  2019.0

# %%
df[(df['Category']=='TV Show') & (df['Rating']=='R') & (df['Year']>2018)].shape
# Out:
# (1, 13)

# %% [markdown]
# ### To find the maximum duration of a movie or show on Netflix using pandas, you would typically need a dataset containing information about movies or shows available on Netflix, including their durations.

# %% [markdown]
# ### str.split()

# %% [markdown]
# ###  Create 2 columns using str.split()

# %%
df[['Minutes','Unit']] = df['Duration'].str.split(' ',expand = True)

# %%
df.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date_N          datetime64[ns]
# Year                   float64
# Minutes                 object
# Unit                    object
# dtype: object

# %% [markdown]
# ### Convert Minutes column to int

# %%
df.Minutes.astype(int)
# Out:
# 0         4
# 1        93
# 2        78
# 3        80
# 4       123
#        ...
# 7784     99
# 7785    111
# 7786     44
# 7787      1
# 7788     90
# Name: Minutes, Length: 7787, dtype: int32

# %%
df.Minutes.astype(int).max()
# Out:
# 312

# %% [markdown]
# ### To find out which individual country has the highest number of TV shows using pandas, you would typically need a dataset containing information about TV shows along with their respective countries of origin.

# %%
tv_show=df[df['Category']=='TV Show']
tv_show.head(2)
# Out:
#   Show_Id Category Title     Director  \
# 0      s1  TV Show    3%          NaN
# 5      s6  TV Show    46  Serdar Akar
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...  Turkey     July 1, 2017
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 5  TV-MA   1 Season    International TV Shows, TV Dramas, TV Mysteries
#
#                                          Description     Date_N    Year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 5  A genetics professor experiments with a treatm... 2017-07-01  2017.0
#
#   Minutes     Unit
# 0       4  Seasons
# 5       1   Season

# %%
tv_show.Country.value_counts()
# Out:
# Country
# United States                                                705
# United Kingdom                                               204
# Japan                                                        157
# South Korea                                                  147
# India                                                         71
#                                                             ...
# Canada, United States, United Kingdom, France, Luxembourg      1
# United States, Italy                                           1
# Chile, Italy                                                   1
# Canada, United Kingdom                                         1
# United States, France, South Korea, Indonesia                  1
# Name: count, Length: 183, dtype: int64

# %%
tv_show.Country.value_counts().head(1)
# Out:
# Country
# United States    705
# Name: count, dtype: int64

# %% [markdown]
# ### To sort a dataset by the 'Year' column using pandas, you can use the 'sort_values()' function.

# %%
df.sort_values('Year',ascending=False)
# Out:
#      Show_Id Category                         Title                 Director  \
# 5564   s5564    Movie               Sherlock Holmes              Guy Ritchie
# 5919   s5919    Movie                     Surf's Up  Ash Brannon, Chris Buck
# 980     s981  TV Show                  Bling Empire                      NaN
# 5955   s5955    Movie              Taare Zameen Par               Aamir Khan
# 366     s367    Movie                     Al acecho      Francisco D'Eufemia
# ...      ...      ...                           ...                      ...
# 3374   s3375  TV Show                      Kikoriki                      NaN
# 3492   s3493  TV Show           La Familia P. Luche                      NaN
# 3946   s3947  TV Show                         Maron                      NaN
# 5138   s5138  TV Show                  Red vs. Blue                      NaN
# 6066   s6066  TV Show  The Adventures of Figaro Pho                      NaN
#
# ...

# %% [markdown]
# ### To find all the instances where Category is 'Movie' and Type is 'Dramas', or Category is 'TV Show' and Type is 'Kids' TV using pandas, you can use boolean indexing with the '&' and '|' operators to combine conditions.

# %%
df[(df['Category']=='Movie') & (df['Type']=='Dramas') 
   | (df['Category']=='TV Show') & (df['Type']=="Kids' TV")]
# Out:
#      Show_Id Category                       Title        Director  \
# 4         s5    Movie                          21  Robert Luketic
# 7         s8    Movie                         187  Kevin Reynolds
# 111     s112  TV Show                     44 Cats             NaN
# 170     s171    Movie                A Family Man   Mark Williams
# 232     s233    Movie  A Stoning in Fulham County   Larry Elikann
# ...      ...      ...                         ...             ...
# 7668   s7667  TV Show               World of Winx  Iginio Straffi
# 7717   s7716  TV Show                        Yoko             NaN
# 7719   s7718  TV Show                         YOM             NaN
# 7758   s7757  TV Show                          Z4             NaN
# 7761   s7760  TV Show                   Zak Storm             NaN
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 7     Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# ...
